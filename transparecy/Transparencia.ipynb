# %% [markdown]
# # Pandaral·lel
#
# Pandaral.lel es una extensión no oficial de Pandas que aporta una forma sencilla de paralelizar las operaciones de pandas.
#
# | Pandas  | ![Without Pandarallel](https://github.com/nalepae/pandarallel/blob/master/docs/progress_apply.gif?raw=true)       |
# | :----------------------: | ----------------------------------------------------------------------------------------------------------------- |
# | **Con paralelización** | ![With Pandarallel](https://github.com/nalepae/pandarallel/blob/master/docs/progress_parallel_apply.gif?raw=true) |
#
# Pandaral·lel está disponible en: https://github.com/nalepae/pandarallel

# %% [markdown]
# # Análisis de sentimientos

# %%
import pandas as pd
from pandarallel import pandarallel
import numpy as np
import re
from textblob import TextBlob

# %% [markdown]
# ## Cargamos el dataset de un CSV

# %%
from IPython.display import display
# Download the dataset from https://www.kaggle.com/kazanova/sentiment140
df = pd.read_csv('./tweets.csv', header=None, sep=',', 
                 names=['target', 'id', 'date', 'flag', 'user', 'text'], encoding='latin-1')
display(df)
# Out:
#          target          id                          date      flag  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# 0        _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          scotthamilton  is upset that he can't update his Facebook by ...
# 2               mattycus  @Kenichan I dived many times for the ball. Man...
# 3                ElleCTF    my whole body feels itchy and like its on fire
# 4                 Karoli  @nationwideclass no, it's not behaving at all....
# ...                  ...                                                ...
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1600000 rows x 6 columns]

# %% [markdown]
# ## Procesado de los tweets

# %%
def preprocess_tweet(text):
    text = re.sub('@[A-Za-z\d]+', '', text)  # Removing @mentions
    text = re.sub('#[A-Za-z\d]+', '', text)  # Removing hashtag
    text = re.sub('https?:\/\/\S+', '', text)  # Removing hyperlink
    # Removing emojis
    text = re.sub(
        '[\u2600-\u26FF\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F1E0-\U0001F1FF]', '',
        text)
    return text

# %%
def discretize_sentiment(text):
    text = preprocess_tweet(text)
    polarity = TextBlob(text).sentiment.polarity
    if polarity < 0:
        return 'negative'
    if polarity == 0:
        return 'neutral'
    if polarity > 0:
        return 'positive'

# %% [markdown]
# ## Realicemos el procesado en local

# %%
pandarallel.initialize(use_memory_fs=False)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
serie = df['text']

# 1 minuto aprox ...
polarity = serie.parallel_apply(discretize_sentiment)
# Out:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-8:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 67, in global_worker
#     return _func(x)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 67, in global_worker
#     return _func(x)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 67, in global_worker
#     return _func(x)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 67, in global_worker
#     return _func(x)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 67, in global_worker
#     return _func(x)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 143, in wrapper
#     result = function(
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 143, in wrapper
#     result = function(
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 67, in global_worker
#     return _func(x)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 67, in global_worker
#     return _func(x)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 143, in wrapper
#     result = function(
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/data_types/series.py", line 20, in worker
#     return series.apply(func, *args, **kwargs)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 67, in global_worker
#     return _func(x)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/data_types/series.py", line 20, in worker
#     return series.apply(func, *args, **kwargs)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 143, in wrapper
#     result = function(
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 143, in wrapper
#     result = function(
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/data_types/series.py", line 20, in worker
#     return series.apply(func, *args, **kwargs)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 143, in wrapper
#     result = function(
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 143, in wrapper
#     result = function(
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/pandarallel.py", line 143, in wrapper
#     result = function(
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/series.py", line 4774, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/data_types/series.py", line 20, in worker
#     return series.apply(func, *args, **kwargs)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/series.py", line 4774, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/data_types/series.py", line 20, in worker
#     return series.apply(func, *args, **kwargs)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/data_types/series.py", line 20, in worker
#     return series.apply(func, *args, **kwargs)
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/data_types/series.py", line 20, in worker
#     return series.apply(func, *args, **kwargs)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1100, in apply
#     return self.apply_standard()
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/series.py", line 4774, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/ubuntu/pycones/transparecy/lib/pandarallel/data_types/series.py", line 20, in worker
#     return series.apply(func, *args, **kwargs)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/series.py", line 4774, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1100, in apply
#     return self.apply_standard()
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/series.py", line 4774, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1151, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1100, in apply
#     return self.apply_standard()
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1151, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/series.py", line 4774, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1100, in apply
#     return self.apply_standard()
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1100, in apply
#     return self.apply_standard()
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/series.py", line 4774, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "pandas/_libs/lib.pyx", line 2919, in pandas._libs.lib.map_infer
#   File "pandas/_libs/lib.pyx", line 2919, in pandas._libs.lib.map_infer
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1151, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1100, in apply
#     return self.apply_standard()
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1151, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1100, in apply
#     return self.apply_standard()
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1151, in apply_standard
#     mapped = lib.map_infer(
#   File "/tmp/ipykernel_799/1737721765.py", line 3, in discretize_sentiment
#     polarity = TextBlob(text).sentiment.polarity
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1151, in apply_standard
#     mapped = lib.map_infer(
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1151, in apply_standard
#     mapped = lib.map_infer(
#   File "/tmp/ipykernel_799/1737721765.py", line 3, in discretize_sentiment
#     polarity = TextBlob(text).sentiment.polarity
#   File "pandas/_libs/lib.pyx", line 2919, in pandas._libs.lib.map_infer
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/series.py", line 4774, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "pandas/_libs/lib.pyx", line 2919, in pandas._libs.lib.map_infer
#   File "pandas/_libs/lib.pyx", line 2919, in pandas._libs.lib.map_infer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [7], line 4
#       1 serie = df['text']
#       3 # 1 minuto aprox ...
# ----> 4 polarity = serie.parallel_apply(discretize_sentiment)
#
# File ~/pycones/transparecy/lib/pandarallel/pandarallel.py:456, in parallelize.<locals>.closure(data, func, *args, **kwargs)
#     453     map_result = pool.map_async(global_worker, workers_args)
#     454     pool.close()
# --> 456     results = get_workers_result(
#     457         use_memory_fs,
#     458         nb_workers,
#     459         progress_bar,
#     460         nb_columns,
#     461         queue,
#     462         chunk_lengths,
#     463         input_files,
#     464         output_files,
#     465         map_result,
#     466     )
#     468     return reduce(results, reduce_meta_args)
#     470 finally:
#
# File ~/pycones/transparecy/lib/pandarallel/pandarallel.py:369, in get_workers_result(use_memory_fs, nb_workers, show_progress_bar, nb_columns, queue, chunk_lengths, input_files, output_files, map_result)
#     366 generation = count()
#     368 while not all(finished_workers):
# --> 369     message_type, message = queue.get()
#     371     if message_type is INPUT_FILE_READ:
#     372         file_index = message
#
# File <string>:2, in get(self, *args, **kwds)
#
# File /usr/lib/python3.10/multiprocessing/managers.py:818, in BaseProxy._callmethod(self, methodname, args, kwds)
#     815     conn = self._tls.connection
#     817 conn.send((self._id, methodname, args, kwds))
# --> 818 kind, result = conn.recv()
#     820 if kind == '#RETURN':
#     821     return result
#
# File /usr/lib/python3.10/multiprocessing/connection.py:255, in _ConnectionBase.recv(self)
#     253 self._check_closed()
#     254 self._check_readable()
# --> 255 buf = self._recv_bytes()
#     256 return _ForkingPickler.loads(buf.getbuffer())
#
# File /usr/lib/python3.10/multiprocessing/connection.py:419, in Connection._recv_bytes(self, maxsize)
#     418 def _recv_bytes(self, maxsize=None):
# --> 419     buf = self._recv(4)
#     420     size, = struct.unpack("!i", buf.getvalue())
#     421     if size == -1:
#
# File /usr/lib/python3.10/multiprocessing/connection.py:384, in Connection._recv(self, size, read)
#     382 remaining = size
#     383 while remaining > 0:
# --> 384     chunk = read(handle, remaining)
#     385     n = len(chunk)
#     386     if n == 0:
#
# KeyboardInterrupt:
#   File "pandas/_libs/lib.pyx", line 2919, in pandas._libs.lib.map_infer
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/decorators.py", line 24, in __get__
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1100, in apply
#     return self.apply_standard()
#   File "/tmp/ipykernel_799/1737721765.py", line 3, in discretize_sentiment
#     polarity = TextBlob(text).sentiment.polarity
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/decorators.py", line 24, in __get__
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/tmp/ipykernel_799/1737721765.py", line 3, in discretize_sentiment
#     polarity = TextBlob(text).sentiment.polarity
#   File "/tmp/ipykernel_799/1737721765.py", line 3, in discretize_sentiment
#     polarity = TextBlob(text).sentiment.polarity
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/apply.py", line 1151, in apply_standard
#     mapped = lib.map_infer(
#   File "/tmp/ipykernel_799/1737721765.py", line 3, in discretize_sentiment
#     polarity = TextBlob(text).sentiment.polarity
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/decorators.py", line 24, in __get__
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/blob.py", line 447, in sentiment
#     return self.analyzer.analyze(self.raw)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/blob.py", line 447, in sentiment
#     return self.analyzer.analyze(self.raw)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/decorators.py", line 24, in __get__
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/decorators.py", line 24, in __get__
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/en/sentiments.py", line 44, in analyze
#     return Sentiment(*pattern_sentiment(text))
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/blob.py", line 447, in sentiment
#     return self.analyzer.analyze(self.raw)
#   File "pandas/_libs/lib.pyx", line 2919, in pandas._libs.lib.map_infer
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/en/sentiments.py", line 44, in analyze
#     return Sentiment(*pattern_sentiment(text))
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/en/sentiments.py", line 44, in analyze
#     return Sentiment(*pattern_sentiment(text))
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 823, in __call__
#     a = self.assessments(((w.lower(), None) for w in " ".join(self.tokenizer(s)).split()), negation)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/blob.py", line 447, in sentiment
#     return self.analyzer.analyze(self.raw)
#   File "/tmp/ipykernel_799/1737721765.py", line 3, in discretize_sentiment
#     polarity = TextBlob(text).sentiment.polarity
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 852, in __call__
#     subjectivity = avg([(w, s) for w, p, s, x in a], weight),
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/en/sentiments.py", line 43, in analyze
#     Sentiment = namedtuple('Sentiment', ['polarity', 'subjectivity'])
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 823, in __call__
#     a = self.assessments(((w.lower(), None) for w in " ".join(self.tokenizer(s)).split()), negation)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/decorators.py", line 24, in __get__
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 868, in assessments
#     if w in self and pos in self[w]:
#   File "/usr/lib/python3.10/collections/__init__.py", line 381, in namedtuple
#     if name.startswith('_') and not rename:
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 868, in assessments
#     if w in self and pos in self[w]:
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/blob.py", line 447, in sentiment
#     return self.analyzer.analyze(self.raw)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 96, in __contains__
#     return self._lazy("__contains__", *args)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/en/sentiments.py", line 43, in analyze
#     Sentiment = namedtuple('Sentiment', ['polarity', 'subjectivity'])
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 84, in _lazy
#     if dict.__len__(self) == 0:
# KeyboardInterrupt
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 96, in __contains__
#     return self._lazy("__contains__", *args)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/decorators.py", line 24, in __get__
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/usr/lib/python3.10/collections/__init__.py", line 414, in namedtuple
#     __new__ = eval(code, namespace)
# KeyboardInterrupt
#   File "<string>", line 1, in <module>
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/blob.py", line 447, in sentiment
#     return self.analyzer.analyze(self.raw)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 80, in _lazy
#     def _lazy(self, method, *args):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/en/sentiments.py", line 43, in analyze
#     Sentiment = namedtuple('Sentiment', ['polarity', 'subjectivity'])
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/blob.py", line 447, in sentiment
#     return self.analyzer.analyze(self.raw)
# KeyboardInterrupt
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/en/sentiments.py", line 43, in analyze
#     Sentiment = namedtuple('Sentiment', ['polarity', 'subjectivity'])
# KeyboardInterrupt
#   File "pandas/_libs/lib.pyx", line 2919, in pandas._libs.lib.map_infer
#   File "/usr/lib/python3.10/collections/__init__.py", line 414, in namedtuple
#     __new__ = eval(code, namespace)
#   File "/tmp/ipykernel_799/1737721765.py", line 3, in discretize_sentiment
#     polarity = TextBlob(text).sentiment.polarity
#   File "<string>", line 1, in <module>
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/decorators.py", line 24, in __get__
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
# KeyboardInterrupt
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/blob.py", line 447, in sentiment
#     return self.analyzer.analyze(self.raw)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/en/sentiments.py", line 44, in analyze
#     return Sentiment(*pattern_sentiment(text))
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 823, in __call__
#     a = self.assessments(((w.lower(), None) for w in " ".join(self.tokenizer(s)).split()), negation)
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 1174, in find_tokens
#     return find_tokens(text_type(string),
#   File "/home/ubuntu/.local/lib/python3.10/site-packages/textblob/_text.py", line 321, in find_tokens
#     sentences[-1].extend(tokens[i:j])
# KeyboardInterrupt

# %% [markdown]
# ## Ahora con la ayuda del cloud...

# %%
pandarallel.initialize(use_memory_fs=False)
# Out:
# INFO: Pandarallel will run on 100 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
serie = df['text']

polarity = serie.parallel_apply(discretize_sentiment)
# Out:
# 2022-10-01 16:12:52,083 [INFO] lithops.config -- Lithops v2.6.0
# 2022-10-01 16:12:52,187 [INFO] lithops.storage.backends.aws_s3.aws_s3 -- S3 client created - Region: eu-central-1
# 2022-10-01 16:12:52,650 [INFO] lithops.serverless.backends.aws_lambda.aws_lambda -- AWS Lambda client created - Region: eu-central-1
# 2022-10-01 16:12:52,652 [INFO] lithops.invokers -- ExecutorID 2b249a-0 | JobID M000 - Selected Runtime: gfinol/python3.10:3.0 - 1769MB
# 2022-10-01 16:13:03,663 [INFO] lithops.invokers -- ExecutorID 2b249a-0 | JobID M000 - Starting function invocation: cloud_process_wrapper() - Total: 100 activations
# 2022-10-01 16:13:03,721 [INFO] lithops.invokers -- ExecutorID 2b249a-0 | JobID M000 - View execution logs at /tmp/lithops/logs/2b249a-0-M000.log
# 2022-10-01 16:13:20,621 [INFO] lithops.wait -- ExecutorID 2b249a-0 - Getting results from 100 function activations
#     0%|          | 0/100
# 2022-10-01 16:13:28,654 [INFO] lithops.executors -- ExecutorID 2b249a-0 - Cleaning temporary data

# %%
polarity.name = "polarity"
display(polarity)
# Out:
# 0          positive
# 1           neutral
# 2          positive
# 3          positive
# 4          negative
#              ...
# 1599995    positive
# 1599996    positive
# 1599997    positive
# 1599998    positive
# 1599999    positive
# Name: polarity, Length: 1600000, dtype: object

# %%
df.assign(polarity = polarity)
# Out:
#          target          id                          date      flag  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text  \
# 0        _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          scotthamilton  is upset that he can't update his Facebook by ...
# 2               mattycus  @Kenichan I dived many times for the ball. Man...
# 3                ElleCTF    my whole body feels itchy and like its on fire
# 4                 Karoli  @nationwideclass no, it's not behaving at all....
# ...                  ...                                                ...
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
#          polarity
# 0        positive
# 1         neutral
# 2        positive
# 3        positive
# 4        negative
# ...           ...
# 1599995  positive
# 1599996  positive
# 1599997  positive
# 1599998  positive
# 1599999  positive
#
# [1600000 rows x 7 columns]
